# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv("/content/drive/MyDrive/Machine Leraning/Breast_Cancer.csv")

# %%
df
# Out:
#            id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0      842302         M  ...                  0.11890          NaN
# 1      842517         M  ...                  0.08902          NaN
# 2    84300903         M  ...                  0.08758          NaN
# 3    84348301         M  ...                  0.17300          NaN
# 4    84358402         M  ...                  0.07678          NaN
# ..        ...       ...  ...                      ...          ...
# 564    926424         M  ...                  0.07115          NaN
# 565    926682         M  ...                  0.06637          NaN
# 566    926954         M  ...                  0.07820          NaN
# 567    927241         M  ...                  0.12400          NaN
# 568     92751         B  ...                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
plt.figure(figsize=[17,19])
sb.countplot(df['diagnosis'].value_counts())
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.drop(['Unnamed: 32', 'id'], axis=1, inplace=True)

# %%
x = df.drop('diagnosis', axis=1)
y = df.diagnosis

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
y = lb.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3,random_state=40)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
xtrain=sc.fit_transform(xtrain)
xtest=sc.transform(xtest)

# %%
import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU, PReLU, ELU
from keras.layers import Dropout

# %%
classifier  = Sequential()

# %%
classifier.add(Dense(units=9, kernel_initializer='he_uniform', activation='relu', input_dim=30))
classifier.add(Dense(units=9, kernel_initializer='he_uniform', activation='relu'))
classifier.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 9)                 279
# _________________________________________________________________
# dense_4 (Dense)              (None, 9)                 90
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 10
# =================================================================
# Total params: 379
# Trainable params: 379
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model = classifier.fit(xtrain,ytrain,batch_size=100,epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6442 - accuracy: 0.6181
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6070 - accuracy: 0.6508
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5722 - accuracy: 0.6960
# Epoch 4/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5403 - accuracy: 0.7412
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5122 - accuracy: 0.7663
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4875 - accuracy: 0.7915
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4639 - accuracy: 0.8216
# Epoch 8/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4427 - accuracy: 0.8618
# Epoch 9/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4229 - accuracy: 0.9020
# Epoch 10/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4056 - accuracy: 0.9196
# Epoch 11/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3880 - accuracy: 0.9472
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3709 - accuracy: 0.9548
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3542 - accuracy: 0.9598
# Epoch 14/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3382 - accuracy: 0.9623
# Epoch 15/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3226 - accuracy: 0.9623
# Epoch 16/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 0.9623
# Epoch 17/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2927 - accuracy: 0.9623
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2791 - accuracy: 0.9623
# Epoch 19/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2664 - accuracy: 0.9648
# Epoch 20/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2546 - accuracy: 0.9648
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2436 - accuracy: 0.9648
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2336 - accuracy: 0.9648
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2241 - accuracy: 0.9648
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2151 - accuracy: 0.9673
# Epoch 25/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2067 - accuracy: 0.9673
# Epoch 26/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1990 - accuracy: 0.9698
# Epoch 27/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1913 - accuracy: 0.9698
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1844 - accuracy: 0.9698
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1778 - accuracy: 0.9724
# Epoch 30/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1718 - accuracy: 0.9724
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1659 - accuracy: 0.9749
# Epoch 32/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9749
# Epoch 33/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1552 - accuracy: 0.9749
# Epoch 34/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1501 - accuracy: 0.9749
# Epoch 35/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9749
# Epoch 36/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1414 - accuracy: 0.9749
# Epoch 37/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1375 - accuracy: 0.9749
# Epoch 38/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1338 - accuracy: 0.9749
# Epoch 39/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9749
# Epoch 40/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1271 - accuracy: 0.9749
# Epoch 41/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.9749
# Epoch 42/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1214 - accuracy: 0.9749
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1186 - accuracy: 0.9749
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1160 - accuracy: 0.9774
# Epoch 45/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1137 - accuracy: 0.9774
# Epoch 46/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1114 - accuracy: 0.9774
# Epoch 47/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9774
# Epoch 48/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 0.9774
# Epoch 49/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1052 - accuracy: 0.9799
# Epoch 50/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1033 - accuracy: 0.9774
# Epoch 51/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1015 - accuracy: 0.9774
# Epoch 52/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0997 - accuracy: 0.9774
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0981 - accuracy: 0.9774
# Epoch 54/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0965 - accuracy: 0.9774
# Epoch 55/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 0.9774
# Epoch 56/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0936 - accuracy: 0.9774
# Epoch 57/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0923 - accuracy: 0.9774
# Epoch 58/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0909 - accuracy: 0.9774
# Epoch 59/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9799
# Epoch 60/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0884 - accuracy: 0.9799
# Epoch 61/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0872 - accuracy: 0.9799
# Epoch 62/100
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0860 - accuracy: 0.9799
# Epoch 63/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0848 - accuracy: 0.9799
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0837 - accuracy: 0.9799
# Epoch 65/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9799
# Epoch 66/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9799
# Epoch 67/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0804 - accuracy: 0.9799
# Epoch 68/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9799
# Epoch 69/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0784 - accuracy: 0.9799
# Epoch 70/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0774 - accuracy: 0.9799
# Epoch 71/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0764 - accuracy: 0.9799
# Epoch 72/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0755 - accuracy: 0.9799
# Epoch 73/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9799
# Epoch 74/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0737 - accuracy: 0.9799
# Epoch 75/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0728 - accuracy: 0.9799
# Epoch 76/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0719 - accuracy: 0.9799
# Epoch 77/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0710 - accuracy: 0.9799
# Epoch 78/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0702 - accuracy: 0.9774
# Epoch 79/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 0.9774
# Epoch 80/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0686 - accuracy: 0.9774
# Epoch 81/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9774
# Epoch 82/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0671 - accuracy: 0.9774
# Epoch 83/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0664 - accuracy: 0.9799
# Epoch 84/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0656 - accuracy: 0.9799
# Epoch 85/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0648 - accuracy: 0.9799
# Epoch 86/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0642 - accuracy: 0.9799
# Epoch 87/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9799
# Epoch 88/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0628 - accuracy: 0.9799
# Epoch 89/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0622 - accuracy: 0.9799
# Epoch 90/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0615 - accuracy: 0.9799
# Epoch 91/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9799
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0604 - accuracy: 0.9799
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0597 - accuracy: 0.9799
# Epoch 94/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0591 - accuracy: 0.9799
# Epoch 95/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 0.9799
# Epoch 96/100
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0580 - accuracy: 0.9799
# Epoch 97/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0576 - accuracy: 0.9799
# Epoch 98/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9799
# Epoch 99/100
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0565 - accuracy: 0.9799
# Epoch 100/100
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0560 - accuracy: 0.9799

# %%
y_pred=classifier.predict(xtest)

# %%
y_pred = (y_pred>0.5)
print(y_pred)
# Out:
# (array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True]]), 5)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
cm = confusion_matrix(ytest, y_pred)
score = accuracy_score(ytest, y_pred)
print(cm)
print('score is:',score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-a3c1f66e0c0f> in <module>()
#       2 from sklearn.metrics import accuracy_score
#       3 # cm = confusion_matrix(ytest, y_pred)
# ----> 4 score = accuracy_score(ytest, y_pred)
#       5 print(cm)
#       6 print('score is:',score)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
#      92     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of binary and continuous targets

# %%
plt.figure(figsize=[14,7])
sb.heatmap(cm,annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-e757c6a109ce> in <module>()
#       1 plt.figure(figsize=[14,7])
# ----> 2 sb.heatmap(cm,annot=True)
#       3 plt.show()
#
# NameError: name 'cm' is not defined

# %%
print(model.history.keys())
plt.plot(model.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy'])

# %%
plt.plot(model.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
